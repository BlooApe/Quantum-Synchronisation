# %%
 import qutip 
from qutip import *
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import pandas as pd
import seaborn as sns
import matplotlib.ticker as ticker

# %%
# From here, we can then go onto find the observed detunings as a function of initial detuning. Then do this for various coupling strengths.

N = 8
a1 = tensor(destroy(N) , qeye(N))
a2 = tensor(qeye(N), destroy(N))

k1 = 1
k2 = (0.1) * k1 

k1_2 = k1
k2_2 = k2 
 
Coupling_rate = 0
D = Coupling_rate * k1 

c1 = np.sqrt(k1) * a1.dag() 
c2 = np.sqrt(k2) * (a1**2)

c3 = np.sqrt(k1) * a2.dag() 
c4 = np.sqrt(k2) * (a2**2) 

c5 = np.sqrt(D) * ( a1 - a2 ) 
Collapse = [c1 , c2 ,c3, c4 , c5]

d_range = np.linspace(0,40,20)
wlist = np.linspace(0, 100, 20000) * 2 * np.pi

frequency_list = []


for d in d_range :
    detuning = d * k1 
    omega = 0
    omega_2 = detuning + omega 

    H = (omega * a1.dag() * a1 + omega_2 * a2.dag() * a2) 

    spec = spectrum(H, wlist, Collapse, a1.dag(), a1)  
    spec_2 = spectrum(H, wlist, Collapse, a2.dag(), a2)  
    
    W_observed = wlist[spec.argmax()]
    W_observed_2 = wlist[spec_2.argmax()]
    mod_W = np.abs(W_observed_2 - W_observed)
    frequency_list.append(mod_W)
    

sns.set_style('whitegrid')
fig, axes = plt.subplots(1, 1, figsize=(5,5))
axes.plot(d_range , frequency_list , 'g' )

plt.title("Entrainment of coupled RVdP oscillators D = 0")
plt.xlabel(r'$ \Delta $ /    $K1$ ')
plt.ylabel(r'|$ \omega1$ - $\omega2 $| /   $K1$ ') 

np.save('Coupled RVDP W vs Detuning , Quantum regime D = 0' , frequency_list)

# %%
# From here, we can then go onto find the observed detunings as a function of initial detuning. Then do this for various coupling strengths.

N = 8
a1 = tensor(destroy(N) , qeye(N))
a2 = tensor(qeye(N), destroy(N))

k1 = 1
k2 = (0.1) * k1 

k1_2 = k1
k2_2 = k2 
 
Coupling_rate = 50
D = Coupling_rate * k1 

c1 = np.sqrt(k1) * a1.dag() 
c2 = np.sqrt(k2) * (a1**2)

c3 = np.sqrt(k1) * a2.dag() 
c4 = np.sqrt(k2) * (a2**2) 

c5 = np.sqrt(D) * ( a1 - a2 ) 
Collapse = [c1 , c2 ,c3, c4 , c5]

d_range = np.linspace(0,40,20)
wlist = np.linspace(0, 100, 20000) * 2 * np.pi

frequency_list_50D = []


for d in d_range :
    detuning = d * k1 
    omega = 0
    omega_2 = detuning + omega 

    H = (omega * a1.dag() * a1 + omega_2 * a2.dag() * a2) 

    spec = spectrum(H, wlist, Collapse, a1.dag(), a1)  
    spec_2 = spectrum(H, wlist, Collapse, a2.dag(), a2)  
    
    W_observed = wlist[spec.argmax()]
    W_observed_2 = wlist[spec_2.argmax()]
    mod_W = np.abs(W_observed_2 - W_observed)
    frequency_list_50D.append(mod_W)
    

sns.set_style('whitegrid')
fig, axes = plt.subplots(1, 1, figsize=(5,5))
axes.plot(d_range , frequency_list_50D , 'g' )

plt.title("Entrainment of coupled RVdP oscillators D = 50")
plt.xlabel(r'$ \Delta $ /    $K1$ ')
plt.ylabel(r'|$ \omega1$ - $\omega2 $| /   $K1$ ') 

np.save('Coupled RVDP W vs Detuning , Quantum regime D = 50' , frequency_list_50D)

# %%
# From here, we can then go onto find the observed detunings as a function of initial detuning. Then do this for various coupling strengths.

N = 5
a1 = tensor(destroy(N) , qeye(N))
a2 = tensor(qeye(N), destroy(N))

k1 = 1
k2 = (0.1) * k1 

k1_2 = k1
k2_2 = k2 
 
Coupling_rate = 30
D = Coupling_rate * k1 

c1 = np.sqrt(k1) * a1.dag() 
c2 = np.sqrt(k2) * (a1**2)

c3 = np.sqrt(k1) * a2.dag() 
c4 = np.sqrt(k2) * (a2**2) 

c5 = np.sqrt(D) * ( a1 - a2 ) 
Collapse = [c1 , c2 ,c3, c4 , c5]

d_range = np.linspace(0,40,40)
wlist = np.linspace(0, 100, 20000) * 2 * np.pi

frequency_list_30D = []


for d in d_range :
    detuning = d * k1 
    omega = 0
    omega_2 = detuning + omega 

    H = (omega * a1.dag() * a1 + omega_2 * a2.dag() * a2) 

    spec = spectrum(H, wlist, Collapse, a1.dag(), a1)  
    
    spec_2 = spectrum(H, wlist, Collapse, a2.dag(), a2)  
    
    W_observed = wlist[spec.argmax()]
    W_observed_2 = wlist[spec_2.argmax()]
    mod_W = np.abs(W_observed_2 - W_observed)
    frequency_list_30D.append(mod_W)
    

sns.set_style('whitegrid')
fig, axes = plt.subplots(1, 1, figsize=(5,5))
axes.plot(d_range , frequency_list_30D , 'g' )

plt.title("Entrainment of coupled RVdP oscillators D = 30")
plt.xlabel(r'$ \Delta $ /    $K1$ ')
plt.ylabel(r'|$ \omega1$ - $\omega2 $| /   $K1$ ') 

np.save('Coupled RVDP W vs Detuning , Quantum regime D = 30' , frequency_list_30D)

# %%
# From here, we can then go onto find the observed detunings as a function of initial detuning. Then do this for various coupling strengths.

N = 5
a1 = tensor(destroy(N) , qeye(N))
a2 = tensor(qeye(N), destroy(N))

k1 = 1
k2 = (0.1) * k1 

k1_2 = k1
k2_2 = k2 
 
Coupling_rate = 10
D = Coupling_rate * k1 

c1 = np.sqrt(k1) * a1.dag() 
c2 = np.sqrt(k2) * (a1**2)

c3 = np.sqrt(k1) * a2.dag() 
c4 = np.sqrt(k2) * (a2**2) 

c5 = np.sqrt(D) * ( a1 - a2 ) 
Collapse = [c1 , c2 ,c3, c4 , c5]

d_range = np.linspace(0,40,40)
wlist = np.linspace(0, 100, 20000) * 2 * np.pi

frequency_list_10D = []


for d in d_range :
    detuning = d * k1 
    omega = 0
    omega_2 = detuning + omega 

    H = (omega * a1.dag() * a1 + omega_2 * a2.dag() * a2) 

    spec = spectrum(H, wlist, Collapse, a1.dag(), a1)  
    
    spec_2 = spectrum(H, wlist, Collapse, a2.dag(), a2)  
    
    W_observed = wlist[spec.argmax()]
    W_observed_2 = wlist[spec_2.argmax()]
    mod_W = np.abs(W_observed_2 - W_observed)
    frequency_list_10D.append(mod_W)
    

sns.set_style('whitegrid')
fig, axes = plt.subplots(1, 1, figsize=(5,5))
axes.plot(d_range , frequency_list_10D , 'g' )

plt.title("Entrainment of coupled RVdP oscillators D = 10")
plt.xlabel(r'$ \Delta $ /    $K1$ ')
plt.ylabel(r'|$ \omega1$ - $\omega2 $| /   $K1$ ') 

np.save('Coupled RVDP W vs Detuning , Quantum regime D = 10' , frequency_list_10D)

# %%
# From here, we can then go onto find the observed detunings as a function of initial detuning. Then do this for various coupling strengths.

N = 5
a1 = tensor(destroy(N) , qeye(N))
a2 = tensor(qeye(N), destroy(N))

k1 = 1
k2 = (0.1) * k1 

k1_2 = k1
k2_2 = k2 
 
Coupling_rate = 5
D = Coupling_rate * k1 

c1 = np.sqrt(k1) * a1.dag() 
c2 = np.sqrt(k2) * (a1**2)

c3 = np.sqrt(k1) * a2.dag() 
c4 = np.sqrt(k2) * (a2**2) 

c5 = np.sqrt(D) * ( a1 - a2 ) 
Collapse = [c1 , c2 ,c3, c4 , c5]

d_range = np.linspace(0,40,40)
wlist = np.linspace(0, 100, 20000) * 2 * np.pi

frequency_list_5D = []


for d in d_range :
    detuning = d * k1 
    omega = 0
    omega_2 = detuning + omega 

    H = (omega * a1.dag() * a1 + omega_2 * a2.dag() * a2) 

    spec = spectrum(H, wlist, Collapse, a1.dag(), a1)  
    
    spec_2 = spectrum(H, wlist, Collapse, a2.dag(), a2)  
    
    W_observed = wlist[spec.argmax()]
    W_observed_2 = wlist[spec_2.argmax()]
    mod_W = np.abs(W_observed_2 - W_observed)
    frequency_list_5D.append(mod_W)
    

sns.set_style('whitegrid')
fig, axes = plt.subplots(1, 1, figsize=(5,5))
axes.plot(d_range , frequency_list_5D , 'g' )

plt.title("Entrainment of coupled RVdP oscillators D = 5")
plt.xlabel(r'$ \Delta $ /    $K1$ ')
plt.ylabel(r'|$ \omega1$ - $\omega2 $| /   $K1$ ') 

np.save('Coupled RVDP W vs Detuning , Quantum regime D = 5' , frequency_list_5D)

# %%
# From here, we can then go onto find the observed detunings as a function of initial detuning. Then do this for various coupling strengths.

N = 5
a1 = tensor(destroy(N) , qeye(N))
a2 = tensor(qeye(N), destroy(N))

k1 = 1
k2 = (0.1) * k1 

k1_2 = k1
k2_2 = k2 
 
Coupling_rate = 20
D = Coupling_rate * k1 

c1 = np.sqrt(k1) * a1.dag() 
c2 = np.sqrt(k2) * (a1**2)

c3 = np.sqrt(k1) * a2.dag() 
c4 = np.sqrt(k2) * (a2**2) 

c5 = np.sqrt(D) * ( a1 - a2 ) 
Collapse = [c1 , c2 ,c3, c4 , c5]

d_range = np.linspace(0,40,40)
wlist = np.linspace(0, 100, 20000) * 2 * np.pi

frequency_list_20D = []


for d in d_range :
    detuning = d * k1 
    omega = 0
    omega_2 = detuning + omega 

    H = (omega * a1.dag() * a1 + omega_2 * a2.dag() * a2) 

    spec = spectrum(H, wlist, Collapse, a1.dag(), a1)  
    
    spec_2 = spectrum(H, wlist, Collapse, a2.dag(), a2)  
    
    W_observed = wlist[spec.argmax()]
    W_observed_2 = wlist[spec_2.argmax()]
    mod_W = np.abs(W_observed_2 - W_observed)
    frequency_list_20D.append(mod_W)
    

sns.set_style('whitegrid')
fig, axes = plt.subplots(1, 1, figsize=(5,5))
axes.plot(d_range , frequency_list_20D , 'g' )

plt.title("Entrainment of coupled RVdP oscillators D = 20")
plt.xlabel(r'$ \Delta $ /    $K1$ ')
plt.ylabel(r'|$ \omega1$ - $\omega2 $| /   $K1$ ') 

np.save('Coupled RVDP W vs Detuning , Quantum regime D = 20' , frequency_list_20D)

# %%
sns.set_style('whitegrid')
frequency_list_RVDP = np.load("Coupled RVDP W vs Detuning , Quantum regime D = 0.npy")
frequency_list_5D_RVDP = np.load("Coupled RVDP W vs Detuning , Quantum regime D = 5.npy") 
frequency_list_10D_RVDP = np.load("Coupled RVDP W vs Detuning , Quantum regime D = 10.npy")
frequency_list_20D_RVDP = np.load("Coupled RVDP W vs Detuning , Quantum regime D = 20.npy")
frequency_list_30D_RVDP = np.load("Coupled RVDP W vs Detuning , Quantum regime D = 30.npy")
frequency_list_50D_RVDP = np.load("Coupled RVDP W vs Detuning , Quantum regime D = 50.npy")

fig, axes = plt.subplots(1, 1,figsize=(10,8))
 
axes.plot(np.linspace(0,40,20) , frequency_list_RVDP , 'b' ,label = 'D = 0')
axes.plot(np.linspace(0,40,40) , frequency_list_5D_RVDP , 'r',label = 'D = 5' )
axes.plot(np.linspace(0,40,40) , frequency_list_10D_RVDP , 'y',label = 'D = 10' )
axes.plot(np.linspace(0,40,40) , frequency_list_20D_RVDP , 'm' ,label = 'D = 20')
axes.plot(np.linspace(0,40,40) , frequency_list_30D_RVDP , 'g' ,label = 'D = 30')
axes.plot(np.linspace(0,40,20) , frequency_list_50D_RVDP , 'k' ,label = 'D = 50')
plt.legend()


plt.title("Entrainment of coupled RVdP oscillators for various Coupling Strengths")
plt.xlabel(r'$ \Delta $ /    $K1$ ')
plt.ylabel(r'|$ \omega1$ - $\omega2 $| /   $K1$ ')
# Out:
# Text(0, 0.5, '|$ \\omega1$ - $\\omega2 $| /   $K1$ ')

# %%
freq_list_VDP = np.load("Coupled VDP W vs Detuning , Quantum Regime D=0.npy")
freq_list_5D_VDP = np.load("Coupled VDP W vs Detuning , Quantum Regime D=5.npy")
freq_list_10D_VDP = np.load("Coupled VDP W vs Detuning , Quantum Regime D=10.npy")
freq_list_20D_VDP = np.load("Coupled VDP W vs Detuning , Quantum Regime D=20.npy")
freq_list_30D_VDP = np.load("Coupled VDP W vs Detuning , Quantum Regime D=30.npy")
freq_list_50D_VDP = np.load("Coupled VDP W vs Detuning , Quantum Regime D=50.npy")

sns.set_style('whitegrid')

fig, axes = plt.subplots(1, 1,figsize=(10,8))
 
axes.plot(np.linspace(0,40,40) , freq_list_VDP, 'b' ,label = 'D = 0')
axes.plot(np.linspace(0,40,40) , freq_list_5D_VDP, 'r',label = 'D = 5' )
axes.plot(np.linspace(0,40,40) , freq_list_10D_VDP , 'y',label = 'D = 10' )
axes.plot(np.linspace(0,40,50) , freq_list_20D_VDP , 'm' ,label = 'D = 20')
axes.plot(np.linspace(0,40,50) , freq_list_30D_VDP , 'g' ,label = 'D = 30')
axes.plot(np.linspace(0,40,50) , freq_list_50D_VDP , 'k' ,label = 'D = 50')
plt.legend()


plt.title("Entrainment of coupled VdP oscillators for various Coupling Strengths")
plt.xlabel(r'$ \Delta $ /    $K1$ ')
plt.ylabel(r'|$ \omega1$ - $\omega2 $| /   $K1$ ') 

#This is quite interesting, so when we take both the RvDP and the VdP oscillator into their quantum regimes ( k2 = 0.1 k1 )
# What we find is that their behaviours are nearly identical, the dotted lines are coupling strengths for the VDP and 
# Bold lines are for the RVdP.
# Out:
# Text(0, 0.5, '|$ \\omega1$ - $\\omega2 $| /   $K1$ ')

# %%
sns.set_style('whitegrid')
frequency_list_R = np.load("Coupled R W vs Detuning , Quantum Regime D=0.npy")
frequency_list_5D_R = np.load("Coupled R W vs Detuning , Quantum Regime D=5.npy") 
frequency_list_10D_R = np.load("Coupled R W vs Detuning , Quantum Regime D=10.npy")
frequency_list_20D_R = np.load("Coupled R W vs Detuning , Quantum regime D=20.npy")
frequency_list_30D_R = np.load("Coupled R W vs Detuning , Quantum regime D=30.npy")
frequency_list_50D_R = np.load("Coupled R W vs Detuning , Quantum regime D=50.npy")

fig, axes = plt.subplots(1, 1,figsize=(10,8))
 
axes.plot(np.linspace(0,40,40) , frequency_list_R , 'b' ,label = 'D = 0')
axes.plot(np.linspace(0,40,40) , frequency_list_5D_R , 'r',label = 'D = 5' )
axes.plot(np.linspace(0,40,40) , frequency_list_10D_R , 'y',label = 'D = 10' )
axes.plot(np.linspace(0,40,40) , frequency_list_20D_R , 'm' ,label = 'D = 20')
axes.plot(np.linspace(0,40,40) , frequency_list_30D_R , 'g' ,label = 'D = 30')
axes.plot(np.linspace(0,40,40) , frequency_list_50D_R , 'k' ,label = 'D = 50')

plt.legend()



plt.title("Entrainment of coupled Rayleigh oscillators for various Coupling Strengths")
plt.xlabel(r'$ \Delta $ /    $K1$ ')
plt.ylabel(r'|$ \omega1$ - $\omega2 $| /   $K1$ ')
# Out:
# Text(0, 0.5, '|$ \\omega1$ - $\\omega2 $| /   $K1$ ')

# %%
sns.set_style('whitegrid')

fig, axes = plt.subplots(1, 1,figsize=(10,8))

axes.plot(np.linspace(0,40,20) , frequency_list_RVDP , 'b' ,label = 'D = 0')
axes.plot(np.linspace(0,40,40) , frequency_list_5D_RVDP , 'r',label = 'D = 5' )
axes.plot(np.linspace(0,40,40) , frequency_list_10D_RVDP , 'y',label = 'D = 10' )
axes.plot(np.linspace(0,40,40) , frequency_list_20D_RVDP , 'm' ,label = 'D = 20')
axes.plot(np.linspace(0,40,40) , frequency_list_30D_RVDP , 'g' ,label = 'D = 30')
axes.plot(np.linspace(0,40,20) , frequency_list_50D_RVDP , 'k' ,label = 'D = 50')
 
axes.plot(np.linspace(0,40,40) , freq_list_VDP, 'b:' ,label = 'D = 0')
axes.plot(np.linspace(0,40,40) , freq_list_5D_VDP, 'r:',label = 'D = 5' )
axes.plot(np.linspace(0,40,40) , freq_list_10D_VDP , 'y:',label = 'D = 10' )
axes.plot(np.linspace(0,40,50) , freq_list_20D_VDP , 'm:' ,label = 'D = 20')
axes.plot(np.linspace(0,40,50) , freq_list_30D_VDP , 'g:' ,label = 'D = 30')
axes.plot(np.linspace(0,40,50) , freq_list_50D_VDP , 'k:' ,label = 'D = 50')
plt.legend()


plt.title("Entrainment of coupled VdP and RVdP oscillators for various Coupling Strengths")
plt.xlabel(r'$ \Delta $ /    $K1$ ')
plt.ylabel(r'|$ \omega1$ - $\omega2 $| /   $K1$ ') 

#This is quite interesting, so when we take both the RvDP and the VdP oscillator into their quantum regimes ( k2 = 0.1 k1 )
# What we find is that their behaviours are nearly identical, the dotted lines are coupling strengths for the VDP and 
# Bold lines are for the RVdP. 

#RVDP and VDP are identical
# Out:
# Text(0, 0.5, '|$ \\omega1$ - $\\omega2 $| /   $K1$ ')

# %%
sns.set_style('whitegrid')

fig, axes = plt.subplots(1, 1,figsize=(10,8))

axes.plot(np.linspace(0,40,20) , frequency_list_RVDP , 'b' ,label = 'D = 0')
axes.plot(np.linspace(0,40,40) , frequency_list_5D_RVDP , 'r',label = 'D = 5' )
axes.plot(np.linspace(0,40,40) , frequency_list_10D_RVDP , 'y',label = 'D = 10' )
axes.plot(np.linspace(0,40,40) , frequency_list_20D_RVDP , 'm' ,label = 'D = 20')
axes.plot(np.linspace(0,40,40) , frequency_list_30D_RVDP , 'g' ,label = 'D = 30')
axes.plot(np.linspace(0,40,20) , frequency_list_50D_RVDP , 'k' ,label = 'D = 50')

axes.plot(np.linspace(0,40,40) , frequency_list_R , 'b:' ,label = 'D = 0')
axes.plot(np.linspace(0,40,40) , frequency_list_5D_R , 'r:',label = 'D = 5' )
axes.plot(np.linspace(0,40,40) , frequency_list_10D_R , 'y:',label = 'D = 10' )
axes.plot(np.linspace(0,40,40) , frequency_list_20D_R , 'm:' ,label = 'D = 20')
axes.plot(np.linspace(0,40,40) , frequency_list_30D_R , 'g:' ,label = 'D = 30')
axes.plot(np.linspace(0,40,40) , frequency_list_50D_R , 'k:' ,label = 'D = 50')
plt.legend()



plt.title("Entrainment of coupled Rayleigh vs RVDP oscillators for various Coupling Strengths")
plt.xlabel(r'$ \Delta $ /    $K1$ ')
plt.ylabel(r'|$ \omega1$ - $\omega2 $| /   $K1$ ')
# Out:
# Text(0, 0.5, '|$ \\omega1$ - $\\omega2 $| /   $K1$ ')

# %%
# This is super strange. that all three oscillator types behave identically in this quantum limit.
